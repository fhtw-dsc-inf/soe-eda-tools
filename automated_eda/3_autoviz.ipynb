# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# %matplotlib inline
# Out:
# Imported v0.1.901. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
filename = "bankdata.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
    save_plot_dir='./plots/'
)
# Out:
# Shape of your Data Set loaded: (45211, 18)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     18 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#     All variables classified into correct types.
# <style type="text/css">
# #T_6e791_row0_col0, #T_6e791_row0_col3, #T_6e791_row0_col4, #T_6e791_row0_col5, #T_6e791_row1_col0, #T_6e791_row1_col3, #T_6e791_row1_col4, #T_6e791_row1_col5, #T_6e791_row2_col0, #T_6e791_row2_col3, #T_6e791_row2_col4, #T_6e791_row2_col5, #T_6e791_row3_col0, #T_6e791_row3_col3, #T_6e791_row3_col4, #T_6e791_row3_col5, #T_6e791_row4_col0, #T_6e791_row4_col3, #T_6e791_row4_col4, #T_6e791_row4_col5, #T_6e791_row5_col0, #T_6e791_row5_col3, #T_6e791_row5_col4, #T_6e791_row5_col5, #T_6e791_row6_col0, #T_6e791_row6_col3, #T_6e791_row6_col4, #T_6e791_row6_col5, #T_6e791_row7_col0, #T_6e791_row7_col3, #T_6e791_row7_col4, #T_6e791_row7_col5, #T_6e791_row8_col0, #T_6e791_row8_col3, #T_6e791_row8_col4, #T_6e791_row8_col5, #T_6e791_row9_col0, #T_6e791_row9_col3, #T_6e791_row9_col4, #T_6e791_row9_col5, #T_6e791_row10_col0, #T_6e791_row10_col3, #T_6e791_row10_col4, #T_6e791_row10_col5, #T_6e791_row11_col0, #T_6e791_row11_col3, #T_6e791_row11_col4, #T_6e791_row11_col5, #T_6e791_row12_col0, #T_6e791_row12_col3, #T_6e791_row12_col4, #T_6e791_row12_col5, #T_6e791_row13_col0, #T_6e791_row13_col3, #T_6e791_row13_col4, #T_6e791_row13_col5, #T_6e791_row14_col0, #T_6e791_row14_col3, #T_6e791_row14_col4, #T_6e791_row14_col5, #T_6e791_row15_col0, #T_6e791_row15_col3, #T_6e791_row15_col4, #T_6e791_row15_col5, #T_6e791_row16_col0, #T_6e791_row16_col3, #T_6e791_row16_col4, #T_6e791_row16_col5, #T_6e791_row17_col0, #T_6e791_row17_col3, #T_6e791_row17_col4, #T_6e791_row17_col5 {
#   font-family: Segoe UI;
# }
# #T_6e791_row0_col1, #T_6e791_row1_col1, #T_6e791_row1_col2, #T_6e791_row2_col1, #T_6e791_row2_col2, #T_6e791_row3_col1, #T_6e791_row3_col2, #T_6e791_row4_col1, #T_6e791_row4_col2, #T_6e791_row5_col1, #T_6e791_row5_col2, #T_6e791_row6_col1, #T_6e791_row7_col1, #T_6e791_row7_col2, #T_6e791_row8_col1, #T_6e791_row8_col2, #T_6e791_row9_col1, #T_6e791_row9_col2, #T_6e791_row10_col1, #T_6e791_row10_col2, #T_6e791_row11_col1, #T_6e791_row11_col2, #T_6e791_row12_col1, #T_6e791_row13_col1, #T_6e791_row13_col2, #T_6e791_row14_col1, #T_6e791_row15_col1, #T_6e791_row15_col2, #T_6e791_row16_col1, #T_6e791_row16_col2, #T_6e791_row17_col1, #T_6e791_row17_col2 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_6e791_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_6e791_row6_col2 {
#   background-color: #fed9c9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_6e791_row12_col2 {
#   background-color: #fff0e9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_6e791_row14_col2 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_6e791">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e791_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_6e791_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_6e791_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_6e791_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_6e791_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_6e791_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e791_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_6e791_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_6e791_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_6e791_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_6e791_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_6e791_row0_col4" class="data row0 col4" >45210.000000</td>
#       <td id="T_6e791_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_6e791_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_6e791_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_6e791_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_6e791_row1_col3" class="data row1 col3" >18.000000</td>
#       <td id="T_6e791_row1_col4" class="data row1 col4" >95.000000</td>
#       <td id="T_6e791_row1_col5" class="data row1 col5" >Column has 487 outliers greater than upper bound (70.50) or lower than lower bound(10.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row2" class="row_heading level0 row2" >job</th>
#       <td id="T_6e791_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_6e791_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_6e791_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_6e791_row2_col3" class="data row2 col3" ></td>
#       <td id="T_6e791_row2_col4" class="data row2 col4" ></td>
#       <td id="T_6e791_row2_col5" class="data row2 col5" >1 rare categories: ['unknown']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row3" class="row_heading level0 row3" >marital</th>
#       <td id="T_6e791_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_6e791_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_6e791_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_6e791_row3_col3" class="data row3 col3" ></td>
#       <td id="T_6e791_row3_col4" class="data row3 col4" ></td>
#       <td id="T_6e791_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row4" class="row_heading level0 row4" >education</th>
#       <td id="T_6e791_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_6e791_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_6e791_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_6e791_row4_col3" class="data row4 col3" ></td>
#       <td id="T_6e791_row4_col4" class="data row4 col4" ></td>
#       <td id="T_6e791_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row5" class="row_heading level0 row5" >default</th>
#       <td id="T_6e791_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_6e791_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_6e791_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_6e791_row5_col3" class="data row5 col3" ></td>
#       <td id="T_6e791_row5_col4" class="data row5 col4" ></td>
#       <td id="T_6e791_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row6" class="row_heading level0 row6" >balance</th>
#       <td id="T_6e791_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_6e791_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_6e791_row6_col2" class="data row6 col2" >15</td>
#       <td id="T_6e791_row6_col3" class="data row6 col3" >-8019.000000</td>
#       <td id="T_6e791_row6_col4" class="data row6 col4" >102127.000000</td>
#       <td id="T_6e791_row6_col5" class="data row6 col5" >Column has 4729 outliers greater than upper bound (3462.00) or lower than lower bound(-1962.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row7" class="row_heading level0 row7" >housing</th>
#       <td id="T_6e791_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_6e791_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_6e791_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_6e791_row7_col3" class="data row7 col3" ></td>
#       <td id="T_6e791_row7_col4" class="data row7 col4" ></td>
#       <td id="T_6e791_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_6e791_level0_row8" class="row_heading level0 row8" >loan</th>
#       <td id="T_6e791_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_6e791_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_6e791_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_6e791_row8_
# Number of All Scatter Plots = 28
# All Plots done
# Time to run AutoViz = 31 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0d6e722b-637b-4e2a-8cdd-8fb747cac04c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
