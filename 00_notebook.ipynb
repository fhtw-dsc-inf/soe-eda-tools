# %%
ticket_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00  163.500000  163.600006  157.201004  159.331497
# 2021-01-05 00:00:00-05:00  158.300507  161.169006  158.253006  160.925507
# 2021-01-06 00:00:00-05:00  157.324005  159.875504  156.557999  156.919006
# 2021-01-07 00:00:00-05:00  157.850006  160.427002  157.750000  158.108002
# 2021-01-08 00:00:00-05:00  159.000000  159.531998  157.110001  159.134995
# ...                               ...         ...         ...         ...
# 2021-12-06 00:00:00-05:00  169.649994  173.695496  166.934494  171.368500
# 2021-12-07 00:00:00-05:00  174.600006  177.499496  173.334503  176.164505
# 2021-12-08 00:00:00-05:00  176.150497  177.179993  174.750504  176.158005
# 2021-12-09 00:00:00-05:00  175.750000  176.969498  174.139496  174.171005
# 2021-12-10 00:00:00-05:00  175.417007  175.927002  170.500000  172.212006
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
DeepnoteChart(ticket_df, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"Volume","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"y":{"bin":true,"sort":null,"type":"quantitative","field":"Open","scale":{"type":"linear"}}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
DeepnoteChart(ticket_df, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"Volume","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"y":{"sort":null,"type":"quantitative","field":"Open","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"count","formatType":"numberFormatFromNumberType"},"size":{"sort":null,"type":"quantitative","field":"Open","aggregate":"sum"}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
DeepnoteChart(ticket_df, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","tooltip":true},"encoding":{"x":{"bin":true,"sort":null,"type":"quantitative","field":"Open","scale":{"type":"linear"}},"y":{"sort":null,"type":"quantitative","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"count","formatType":"numberFormatFromNumberType"},"size":{"sort":null,"type":"quantitative","field":"Open","aggregate":"sum"},"color":{"sort":null,"type":"quantitative","field":"High","scale":{"scheme":"blues"},"aggregate":"sum"}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
pd.read_csv('spotify_data/dataset/songs_artists_album/spotify_tracks.csv')
# Out:
#         Unnamed: 0  acousticness                album_id  \
# 0                0      0.294000  0D3QufeCudpQANOR7luqdr
# 1                1      0.863000  1bcqsH5UyTBzmh9YizdsBE
# 2                2      0.750000  4tKijjmxGClg4JOLAyo2qE
# 3                3      0.763000  6FeJF5r8roonnKraJxr4oB
# 4                4      0.770000  4tKijjmxGClg4JOLAyo2qE
# ...            ...           ...                     ...
# 101934      101934      0.005640  1M9n4vCmOH4lbcHrpt21Qy
# 101935      101935      0.000406  511p6iaCuK8Sr0BYdpcfkq
# 101936      101936      0.004510  511p6iaCuK8Sr0BYdpcfkq
# 101937      101937      0.333000  7H3Bgvb3hs4vvLwccHDRlr
# 101938      101938      0.028400  3oieBBYbUOve0VpxTCpHr1
#
#                                              analysis_url  \
# 0       https://api.spotify.com/v1/audio-analysis/5qlj...
# 1       https://api.spotify.com/v1/audio-analysis/3VAX...
# 2       https://api.spotify.com/v1/audio-analysis/1L3Y...
# ...

# %%
df_1 = _deepnote_execute_sql('select * from \n\'spotify_data/dataset/songs_artists_album/spotify_artists.csv\' artists\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_1
# Out:
#        column0  artist_popularity  followers  \
# 0            0                 44      23230
# 1            1                 22        313
# 2            2                 26       1596
# 3            3                 31        149
# 4            4                 21         11
# ...        ...                ...        ...
# 56124    56124                 23       1212
# 56125    56125                 42      57973
# 56126    56126                 38      20870
# 56127    56127                 44      33923
# 56128    56128                 44      42026
#
#                                                   genres  \
# 0      ['sertanejo', 'sertanejo pop', 'sertanejo trad...
# 1                                                     []
# 2                                    ['danish pop rock']
# 3                                 ['uk alternative pop']
# 4                                     ['french baroque']
# ...                                                  ...
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0d6e722b-637b-4e2a-8cdd-8fb747cac04c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
